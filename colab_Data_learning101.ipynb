# %% [markdown]
# <a href="https://colab.research.google.com/github/aaronhuang317/Data-leaing101/blob/main/colab_Data_learning101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 掛載 Google Drive，以便訪問儲存在雲端硬碟中的檔案
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 導入 pandas 庫，用於數據處理和分析
import pandas as pd

# 從 Google Drive 讀取 CSV 檔案到 DataFrame 中
df = pd.read_csv("/content/drive/MyDrive/python 商業分析/coffee_shop.csv 的副本")

# 顯示 DataFrame 的類型，確認它是一個 pandas DataFrame 物件
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# 顯示 DataFrame 的前幾行，快速預覽數據內容
df.head()
# Out:
#    OrderID        Date     Product  ... Quantity  Member      Payment
# 0     1001  2026-07-01       Latte  ...        2     Yes  Credit Card
# 1     1002  2026-07-01   Americano  ...        1      No         Cash
# 2     1003  2026-07-01  Cappuccino  ...        1     Yes   Mobile Pay
# 3     1004  2026-07-01  Cheesecake  ...        2      No  Credit Card
# 4     1005  2026-07-01      Cookie  ...        3     Yes         Cash
#
# [5 rows x 8 columns]

# %%
# 選取並顯示 DataFrame 中指定欄位的數據 ('Product', 'Category', 'Price', 'Quantity')
df[['Product', 'Category', 'Price', 'Quantity']]
# Out:
#        Product Category  Price  Quantity
# 0        Latte   Coffee    120         2
# 1    Americano   Coffee     90         1
# 2   Cappuccino   Coffee    130         1
# 3   Cheesecake  Dessert    150         2
# 4       Cookie  Dessert     60         3
# 5        Mocha   Coffee    140         1
# 6        Latte   Coffee    120         1
# 7      Brownie  Dessert     80         2
# 8    Americano   Coffee     90         2
# 9          Tea    Drink     70         3
# 10       Latte   Coffee    120         2
# 11      Cookie  Dessert     60         4
# 12       Mocha   Coffee    140         1
# 13         Tea    Drink     70         2
# 14  Cappuccino   Coffee    130         2
# 15  Cheesecake  Dessert    150         1
# 16   Americano   Coffee     90         3
# 17       Latte   Coffee    120         1
# 18     Brownie  Dessert     80         2
# 19         Tea    Drink     70         4
# 20       Mocha   Coffee    140         2
# 21      Cookie  Dessert     60         2
# ...

# %%
# 創建一個新欄位 'Totalprice'，計算每個商品的總價格 (Price * Quantity)
df['Totalprice'] = df['Price'] * df['Quantity']
# 顯示更新後 DataFrame 的前幾行，包含新的 'Totalprice' 欄位
df.head()
# Out:
#    OrderID        Date     Product  ... Member      Payment  Totalprice
# 0     1001  2026-07-01       Latte  ...    Yes  Credit Card         240
# 1     1002  2026-07-01   Americano  ...     No         Cash          90
# 2     1003  2026-07-01  Cappuccino  ...    Yes   Mobile Pay         130
# 3     1004  2026-07-01  Cheesecake  ...     No  Credit Card         300
# 4     1005  2026-07-01      Cookie  ...    Yes         Cash         180
#
# [5 rows x 9 columns]

# %%
# 根據 'Product' 欄位對 DataFrame 進行分組
group = df.groupby('Product')
# 顯示分組物件的類型及其包含的組數
print(type(group)) , len(group)

# 以下是被註釋掉的程式碼，用於遍歷並印出每個產品組的項目數量，目前未執行
#print("\n每個產品的項目數量：")
#for product_name, group_data in group:
 #   print(f"產品: {product_name}, 數量: {len(group_data)}")
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>
# (None, 8)

# %%
# 遍歷根據 'Product' 欄位分組後的每個產品群組
for product_name , group_data in df.groupby('Product'):
  # 顯示產品名稱以及該產品群組包含的數據筆數
  print("產品名稱" , product_name, "共" ,len(group_data),"筆")
  # 顯示當前產品群組的所有數據
  display (group_data)
  print()
# Out:
# 產品名稱 Americano 共 5 筆
#     OrderID        Date    Product  ... Member      Payment  Totalprice
# 1      1002  2026-07-01  Americano  ...     No         Cash          90
# 8      1009  2026-07-02  Americano  ...     No  Credit Card         180
# 16     1017  2026-07-04  Americano  ...    Yes         Cash         270
# 22     1023  2026-07-06  Americano  ...    Yes  Credit Card         180
# 28     1029  2026-07-07  Americano  ...    Yes         Cash         180
#
# [5 rows x 9 columns]
# 產品名稱 Brownie 共 3 筆
#     OrderID        Date  Product  ... Member      Payment  Totalprice
# 7      1008  2026-07-02  Brownie  ...    Yes         Cash         160
# 18     1019  2026-07-05  Brownie  ...    Yes  Credit Card         160
# 27     1028  2026-07-07  Brownie  ...     No  Credit Card         240
#
# [3 rows x 9 columns]
# 產品名稱 Cappuccino 共 3 筆
#     OrderID        Date     Product  ... Member     Payment  Totalprice
# 2      1003  2026-07-01  Cappuccino  ...    Yes  Mobile Pay         130
# ...

# %%
# 從依 'Member' 欄位分組的數據中，取出 'Yes' 成員的所有數據
group_member_Yes = df.groupby('Member').get_group('Yes')
# 顯示取出數據的類型及其筆數
print(type(group_member_Yes),len(group_member_Yes))
# 顯示取出數據的前幾行
display(group_member_Yes.head())
print()
# Out:
# <class 'pandas.core.frame.DataFrame'> 18
#    OrderID        Date     Product  ... Member      Payment  Totalprice
# 0     1001  2026-07-01       Latte  ...    Yes  Credit Card         240
# 2     1003  2026-07-01  Cappuccino  ...    Yes   Mobile Pay         130
# 4     1005  2026-07-01      Cookie  ...    Yes         Cash         180
# 6     1007  2026-07-02       Latte  ...    Yes  Credit Card         120
# 7     1008  2026-07-02     Brownie  ...    Yes         Cash         160
#
# [5 rows x 9 columns]

# %%
# 從依 'Product' 欄位分組的數據中，取出 'Latte' 產品的所有數據
latte_costermer = df.groupby('Product').get_group('Latte')
# 顯示取出數據的類型及其筆數
print(type(latte_costermer),len(latte_costermer))
# 顯示取出數據的所有內容
display(latte_costermer)
print()
# Out:
# <class 'pandas.core.frame.DataFrame'> 6
#     OrderID        Date Product  ... Member      Payment  Totalprice
# 0      1001  2026-07-01   Latte  ...    Yes  Credit Card         240
# 6      1007  2026-07-02   Latte  ...    Yes  Credit Card         120
# 10     1011  2026-07-03   Latte  ...    Yes  Credit Card         240
# 17     1018  2026-07-05   Latte  ...     No   Mobile Pay         120
# 23     1024  2026-07-06   Latte  ...     No   Mobile Pay         360
# 29     1030  2026-07-07   Latte  ...    Yes  Credit Card         240
#
# [6 rows x 9 columns]

# %%
# 使用布林索引篩選出 'Product' 為 'Latte' 且 'Member' 為 'Yes' 的數據
latte_costermer_member = df[(df["Product"]=="Latte") & (df["Member"]=="Yes")]
# 顯示篩選後數據的類型及其筆數
print(type(latte_costermer_member),len(latte_costermer_member))
# 顯示篩選後數據的所有內容
display(latte_costermer_member)
print()
# Out:
# <class 'pandas.core.frame.DataFrame'> 4
#     OrderID        Date Product  ... Member      Payment  Totalprice
# 0      1001  2026-07-01   Latte  ...    Yes  Credit Card         240
# 6      1007  2026-07-02   Latte  ...    Yes  Credit Card         120
# 10     1011  2026-07-03   Latte  ...    Yes  Credit Card         240
# 29     1030  2026-07-07   Latte  ...    Yes  Credit Card         240
#
# [4 rows x 9 columns]

# %%
# 以下是被註釋掉的程式碼，用於從依多個欄位 ('Product', 'Member') 分組的數據中，取出 'Latte' 和 'Yes' 的組合數據
#latte_costermer_member = df.groupby(['Product','Member']).get_group(('Latte','Yes'))
#print(type(latte_costermer_member),len(latte_costermer_member))
#display(latte_costermer_member)
#print()
# Out:
# <class 'pandas.core.frame.DataFrame'> 4
#     OrderID        Date Product  ... Member      Payment  Totalprice
# 0      1001  2026-07-01   Latte  ...    Yes  Credit Card         240
# 6      1007  2026-07-02   Latte  ...    Yes  Credit Card         120
# 10     1011  2026-07-03   Latte  ...    Yes  Credit Card         240
# 29     1030  2026-07-07   Latte  ...    Yes  Credit Card         240
#
# [4 rows x 9 columns]

# %%
# 遍歷根據 'Product' 欄位分組後的每個產品群組
for product_name , sele_number in df.groupby("Product"):
  # 計算並顯示每個產品的總銷售數量
  print("產品名稱" , product_name, "共" ,sele_number['Quantity'].sum(),"單")
# Out:
# 產品名稱 Americano 共 10 單
# 產品名稱 Brownie 共 7 單
# 產品名稱 Cappuccino 共 5 單
# 產品名稱 Cheesecake 共 5 單
# 產品名稱 Cookie 共 9 單
# 產品名稱 Latte 共 11 單
# 產品名稱 Mocha 共 4 單
# 產品名稱 Tea 共 10 單

# %%
# 遍歷根據 'Product' 欄位分組後的每個產品群組
for product_name , sele_number in df.groupby("Product"):
  # 計算當前產品群組的總銷售數量
  total_sales = sele_number['Quantity'].sum()
  print("產品名稱" , product_name, "共" ,total_sales,"單")

  # 取得當前產品的單價 (假設同一產品的價格是固定的，取第一個)
  price_per_item = sele_number['Price'].iloc[0]
  # 計算並列印該產品的總銷售額
  print(f"產品: {product_name}, 總銷售數量: {total_sales} x 單價: {price_per_item} = {total_sales * price_per_item}")
